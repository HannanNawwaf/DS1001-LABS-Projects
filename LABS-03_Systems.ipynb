# %% [markdown]
# # LABS-3: Systems Project
#
# In this notebook you will run a few cells to ensure that your environment is properly set up.

# %%
## First cell
# run this for step 11 in your instructions

print("Hello, World!")
# Out:
# Hello, World!

# %%
## Second cell
# run this for step 14 in your instructions

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[53], line 4
#       1 ## Second cell
#       2 # run this for step 14 in your instructions
# ----> 4 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
## Part 3: Accessing your data
# edit this code to load your data into your workspace

data = pd.read_csv('imdb_movies.csv') #add your data file path to this line!
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       1 ## Part 3: Accessing your data
#       2 # edit this code to load your data into your workspace
# ----> 4 data = pd.read_csv('imdb_movies.csv') #add your data file path to this line!
#       5 data.head()
#
# NameError: name 'pd' is not defined
